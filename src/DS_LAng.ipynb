# %%
import logging
import pandas as pd
import numpy as np
from numpy import random

import nltk
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
import re
from bs4 import BeautifulSoup

# %%
#input_training
preffered_labels = ['en',  'kn', 'ta', 'gu', 'bn', 'te', 'hi', 'mr','ml']
import bs4
from bs4 import BeautifulSoup
infile = open(r'C:\Users\SUBHAM\Downloads\IDRBT-FIRE-master\IDRBT-FIRE-master\dataFIRE\InputTraining.txt',encoding="utf8")
contents = infile.read()

input_file = open(r'C:\Users\SUBHAM\Desktop\DS-LanguageClass\inputLangData.txt','w',encoding="utf8")

soup = BeautifulSoup(contents)
titles = soup.find_all('utterance')
for title in titles:
    input_file.write(title.get_text())

input_file.close()
infile.close()

# %%
from nltk.tokenize import word_tokenize
inputfile = open(r'C:\Users\SUBHAM\Desktop\DS-LanguageClass\inputLangData.txt','r',encoding="utf8")
text = inputfile.read()
input_list = text.split()
print(len(input_list))
inputfile.close()
# print(input_list)
# Out:
# 51504

# %%
#input_testing

import bs4
from bs4 import BeautifulSoup
infile = open(r'C:\Users\SUBHAM\Downloads\IDRBT-FIRE-master\IDRBT-FIRE-master\dataFIRE\InputTesting.txt',encoding="utf8")
contents = infile.read()

input_file = open(r'C:\Users\SUBHAM\Desktop\DS-LanguageClass\TestinputLangData.txt','w',encoding="utf8")

soup = BeautifulSoup(contents)
titles = soup.find_all('utterance')
for title in titles:
    input_file.write(title.get_text())

input_file.close()
infile.close()

# %%
from nltk.tokenize import word_tokenize
inputfile = open(r'C:\Users\SUBHAM\Desktop\DS-LanguageClass\TestinputLangData.txt','r',encoding="utf8")
text = inputfile.read()
test_input_list = text.split()
print(len(test_input_list))
inputfile.close()
print(test_input_list[0:])
# Out:
# 11999
# ['and', 'lightening', 'exabits', 'in', 'videos', 'http://t.co/s22zrne4bx', 'gigabits', 'transfer', 'll', 'delhi', 'watch', 'air', 'will', 'of', 'be', '#aapstorm', 'data', '#aapsweep', '12.', 'rogi', ':', 'doctor', ',', 'ondu', 'vishayadhalli', 'neevu', 'tumbhaa', 'lucky', '.', 'rt', 'trending', 'trendsmapindia', 'is', 'india', '#aapstorm', 'http://t.co/gpohawcwwo', 'in', 'now', 'mahesh', 'babu', '.', 'davudu', 'lanti', 'vadu', '.......', 'ninna', 'malligeya', 'ka0pige', 'Amar', 'ubuntute', 'sudo', 'apt', 'gete', 'kono', 'download', 'hochhena', 'keno', 'Aman', 'Sharma', '(', 'Unknown', ')', 'suchit', 'yadav', 'aapp', 'pm', 'zarur', 'banege', 'modiji', 'din', 'ani', 'din', 'khai', 'population', 'in', 'kolkata', 'anna', 'erju', 'malli', 'velina', 'movie', '.....', 'enno', 'sari', 'chudatam', 'MARCHIPOYA', 'wow', '..', 'admin', 'tune', 'joke', 'crack', 'kiya', 'h', '?', 'mtlb', 'ab', 'hum', 'haase', 'bhi', ':P', 'ab', 'tasalli', 'hoe', 'gayee', 'secular', 'kuttoe', 'koe', 'gujarati', 'moms', 'rt', '@saurav_mrigank', '#aapstorm', '#delhidecides', 'touts', 'bags', 'amid', 'rto', 'delhi', '#aapsweep', 'results', 'elections', 'their', 'at', '2015', 'pack', 'change', 'regime', 'Ee', 'haadu', 'bartiddaaga', 'nam', 'frnd', 'obba', '“', 'papa', 'Jaundice', 'irbeku', '"', 'andiddaa', '...', 'lol', '17.', 'ganda', ':', 'neenu', 'adige', 'tumbhaa', 'chennaagi', 'maadteeya', 'kane', '.', 'bola', '#aapstorm', 'words', 'g', 'sabse', 'denge', 'of', 'ko', 'samjha', 'hum', 'winning', 'to', 'reason', 'candidates', 'aap', '#kiranbedi', 'bjp', 'vote', 'main', 'tha', 'kro', 'tai', 'yancha', 'far', 'chan', 'abhinya', ',', 'ek', 'sundar', 'aitehasik', 'chtrapat', ',', 'sarja', 'aasava', 'tar', 'loss', 'kapil', 'his', '#withbjpalways', 'stands', 'for', 'absolutely', '#aapsweep', 'is', 'sibal', 'apt', '#aapstorm', 'zero', 'vindicated', 'congress', 'today', 'theory', 'name', 'ar', 'ki', 'ache', 'ke', 'bolechilen', 'Gorkhaland', 'sankranto', 'khabar', 'pwolichu', 'mone', '……', 'Uttam', 'suchitrar', 'chabir', 'gan', 'download', 'Awesome', 'Okari', 'Okaru', 'Raksha', 'and', 'said', 'business', 'bjpins', '#aapsweep', 'is', 'some', '#aapstorm', 'http://t.co/cnhhmkkckd', 'anti', 'aap', 'what', 'they', 'actualy', 'mean', '...', 'death', 'or', 'what', '...', ':(', 'kohli', 'ki', 'consistency', 'indian', 'team', 'lineup', 'pehli', 'pehli', 'baar', 'milaata', 'hai', 'yehi', 'mp3', 'aaja', 'aaja', 'dil', 'nichode', 'lyrics', 'peler', 'khyala', 'ami', 'dekhini', '...', 'maradona', 'bolte', 'smritite', 'jiv', 'ber', 'kore', 'or', 'saara', 'maath', 'dour', '..', 'sebari', 'nirbaasito', 'holo', 'maradona', '..', 'dekhechhi', 'zidan', 'ke', '..', 'kintu', 'maradona', 'jakhon', 'world', 'cup', 'arzentina', 'ke', 'coaching', 'korachhe', 'aagerbaar', '..', 'sideline-e', 'dariye', 'thaka', 'oi', 'bitorkito', 'r', 'mota', 'loktaake', 'dekhe', 'gaayer', 'rom', 'khaara', 'hoye', 'jachhilo', 'eta', 'dekhe', '..', 'what', 'a', 'come', 'back', '..', 'jhora', 'patar', 'majhe', 'Mahesh', 'anna', 'meru', 'trailers', 'share', 'chesina', 'cheyyaka', 'poina', 'memu', 'share', 'chesthane', 'untam', '.....', 'we', 'are', 'here', 'to', 'support', 'you', '....', 'Actually', 'avne', 'frst', 'txt', 'maadidhu', 'pawan', 'singh', 'lodhi', 'itne', 'bomb', 'blast', 'hue', 'hai', 'kuch', 'to', 'iske', 'liye', 'samyedna', 'prakat', 'kar', 'le', 'yogesh', 'chauhan', 'sorry', 'bat', 'samaj', 'nahi', 'aae', 'Ulla', 'pona', 'udane', 'random', 'order', 'la', 'ukkara', 'vechaanga', '..', 'En', 'roll', 'no', 'munnadiye', 'varum', 'nrathu', 'naala', 'naan', 'mudhallaye', 'lab', 'kulla', 'poitten', '..', 'Enakku', 'vantha', 'seat', 'Fig', '.', 'la', 'irukku', '.', ';', '-', ')', '.', 'Enakku', 'pakkathula', 'rendu', 'seat', 'ume', 'initial', 'la', 'gaali', 'a', 'thaan', 'irunthuthu', '..', 'Seri', 'ethaavathu', 'vishayam', 'therinjavanga', 'vantha', 'oru', 'support', 'a', 'irukkume', '.', 'feeling', 'democracy', 'for', 'i', 'india', 'is', 'in', 'm', 'days', '#aapstorm', '@asadowaisi', '#aapsweep', 'time', 't ...

# %%
#Input Labels

import bs4
from bs4 import BeautifulSoup
infile = open(r'C:\Users\SUBHAM\Downloads\IDRBT-FIRE-master\IDRBT-FIRE-master\dataFIRE\AnnotationTraining.txt',encoding="utf8")
contents = infile.read()

input_file = open(r'C:\Users\SUBHAM\Desktop\DS-LanguageClass\myDSInput.txt','w',encoding="utf8")

soup = BeautifulSoup(contents)
titles = soup.find_all('utterance')
for title in titles:
    input_file.write(title.get_text())

input_file.close()

labelfile = open(r'C:\Users\SUBHAM\Desktop\DS-LanguageClass\myDSInput.txt','r',encoding="utf8")
text = labelfile.read()
label_list = text.split()
print(len(label_list))
labelfile.close()
# print(label_list)
# Out:
# 51504

# %%
#Input test Labels

import bs4
from bs4 import BeautifulSoup
infile = open(r'C:\Users\SUBHAM\Downloads\IDRBT-FIRE-master\IDRBT-FIRE-master\dataFIRE\AnnotationTesting.txt',encoding="utf8")
contents = infile.read()

input_file = open(r'C:\Users\SUBHAM\Desktop\DS-LanguageClass\TestmyDSInputLabel.txt','w',encoding="utf8")

soup = BeautifulSoup(contents)
titles = soup.find_all('utterance')
for title in titles:
    input_file.write(title.get_text())

input_file.close()

labelfile = open(r'C:\Users\SUBHAM\Desktop\DS-LanguageClass\TestmyDSInputLabel.txt','r',encoding="utf8")
text = labelfile.read()
test_label_list = text.split()
print(len(test_label_list))
labelfile.close()
# print(test_label_list)
# Out:
# 11999

# %%
map_input_label = {}
total_vocab=set()
new_input=[]
new_label=[]
X_trainActual=[]
y_trainActual=[]
for m in range(len(label_list)):
    if label_list[m] in preffered_labels:
        allstrings = []
        allstrings = [input_list[m][i: j] for i in range(len(input_list[m])) for j in range(i+3, len(input_list[m]) + 1)] 
        buf1 = []
        if len(allstrings)>0:
            for n in allstrings:
                if len(n)<=6:
                    new_input.append(n)
                    new_label.append(label_list[m])
                    buf1.append(n)
            X_trainActual.append(buf1)
            y_trainActual.append(label_list[m])
#         myfile = open("C:\\Users\\SUBHAM\\Desktop\\DS-LanguageClass\\"+label_list[i]+".txt",'a',encoding="utf8")
#         total_vocab.add(n)
#         if label_list[m] in map_input_label:
#             if n in map_input_label[label_list[m]]:
#                 map_input_label[label_list[m]][n] += 1
#             else:
#                 map_input_label[label_list[m]][n] = 1
#         else:
#             map_input_label[label_list[m]]={}
                
       
# total_vocab = list(total_vocab)
print(len(X_trainActual))
print(len(y_trainActual))
print(len(new_input),len(new_label))
# Out:
# 34500
# 34500
# 339748 339748

# %%
#X_test and Y_test

X_test=[]
y_test=[]
X_testActual=[]
y_testActual=[]
refresh_test_list = []
for m in range(len(test_label_list)):
    if test_label_list[m] in preffered_labels:
        allstrings = []
        allstrings = [test_input_list[m][i: j] for i in range(len(test_input_list[m])) for j in range(i+3, len(test_input_list[m]) + 1)] 
        buf = []
        if len(allstrings)>0:
            for n in allstrings:
                if len(n)<=6:
                    X_test.append(n)
                    y_test.append(test_label_list[m])
                    buf.append(n)
            refresh_test_list.append(test_input_list[m])
            X_testActual.append(buf)
            y_testActual.append(test_label_list[m])

# %%
print(len(X_testActual),len(y_testActual))
# print(X_testActual)
print(X_test)
print()
# Out:
# 8050 8050
# ['and', 'lig', 'ligh', 'light', 'lighte', 'igh', 'ight', 'ighte', 'ighten', 'ght', 'ghte', 'ghten', 'ghteni', 'hte', 'hten', 'hteni', 'htenin', 'ten', 'teni', 'tenin', 'tening', 'eni', 'enin', 'ening', 'nin', 'ning', 'ing', 'exa', 'exab', 'exabi', 'exabit', 'xab', 'xabi', 'xabit', 'xabits', 'abi', 'abit', 'abits', 'bit', 'bits', 'its', 'vid', 'vide', 'video', 'videos', 'ide', 'ideo', 'ideos', 'deo', 'deos', 'eos', 'gig', 'giga', 'gigab', 'gigabi', 'iga', 'igab', 'igabi', 'igabit', 'gab', 'gabi', 'gabit', 'gabits', 'abi', 'abit', 'abits', 'bit', 'bits', 'its', 'tra', 'tran', 'trans', 'transf', 'ran', 'rans', 'ransf', 'ransfe', 'ans', 'ansf', 'ansfe', 'ansfer', 'nsf', 'nsfe', 'nsfer', 'sfe', 'sfer', 'fer', 'wat', 'watc', 'watch', 'atc', 'atch', 'tch', 'air', 'wil', 'will', 'ill', 'dat', 'data', 'ata', 'rog', 'rogi', 'ogi', 'doc', 'doct', 'docto', 'doctor', 'oct', 'octo', 'octor', 'cto', 'ctor', 'tor', 'ond', 'ondu', 'ndu', 'vis', 'vish', 'visha', 'vishay', 'ish', 'isha', 'ishay', 'ishaya', 'sha', 'shay', 'shaya', 'shayad', 'hay', 'haya', 'hayad', 'hayadh', 'aya', 'ayad', 'ayadh', 'ayadha', 'yad', 'yadh', 'yadha', 'yadhal', 'adh', 'adha', 'adhal', 'adhall', 'dha', 'dhal', 'dhall', 'dhalli', 'hal', 'hall', 'halli', 'all', 'alli', 'lli', 'nee', 'neev', 'neevu', 'eev', 'eevu', 'evu', 'tum', 'tumb', 'tumbh', 'tumbha', 'umb', 'umbh', 'umbha', 'umbhaa', 'mbh', 'mbha', 'mbhaa', 'bha', 'bhaa', 'haa', 'luc', 'luck', 'lucky', 'uck', 'ucky', 'cky', 'tre', 'tren', 'trend', 'trendi', 'ren', 'rend', 'rendi', 'rendin', 'end', 'endi', 'endin', 'ending', 'ndi', 'ndin', 'nding', 'din', 'ding', 'ing', 'tre', 'tren', 'trend', 'trends', 'ren', 'rend', 'rends', 'rendsm', 'end', 'ends', 'endsm', 'endsma', 'nds', 'ndsm', 'ndsma', 'ndsmap', 'dsm', 'dsma', 'dsmap', 'dsmapi', 'sma', 'smap', 'smapi', 'smapin', 'map', 'mapi', 'mapin', 'mapind', 'api', 'apin', 'apind', 'apindi', 'pin', 'pind', 'pindi', 'pindia', 'ind', 'indi', 'india', 'ndi', 'ndia', 'dia', 'now', 'dav', 'davu', 'davud', 'davudu', 'avu', 'avud', 'avudu', 'vud', 'vudu', 'udu', 'lan', 'lant', 'lanti', 'ant', 'anti', 'nti', 'vad', 'vadu', 'adu', 'nin', 'ninn', 'ninna', 'inn', 'inna', 'nna', 'mal', 'mall', 'malli', 'mallig', 'all', 'alli', 'allig', 'allige', 'lli', 'llig', 'llige', 'lligey', 'lig', 'lige', 'ligey', 'ligeya', 'ige', 'igey', 'igeya', 'gey', 'geya', 'eya', 'Ama', 'Amar', 'mar', 'kon', 'kono', 'ono', 'dow', 'down', 'downl', 'downlo', 'own', 'ownl', 'ownlo', 'ownloa', 'wnl', 'wnlo', 'wnloa', 'wnload', 'nlo', 'nloa', 'nload', 'loa', 'load', 'oad', 'hoc', 'hoch', 'hochh', 'hochhe', 'och', 'ochh', 'ochhe', 'ochhen', 'chh', 'chhe', 'chhen', 'chhena', 'hhe', 'hhen', 'hhena', 'hen', 'hena', 'ena', 'ken', 'keno', 'eno', 'Unk', 'Unkn', 'Unkno', 'Unknow', 'nkn', 'nkno', 'nknow', 'nknown', 'kno', 'know', 'known', 'now', 'nown', 'own', 'suc', 'such', 'suchi', 'suchit', 'uch', 'uchi', 'uchit', 'chi', 'chit', 'hit', 'yad', 'yada', 'yadav', 'ada', 'adav', 'dav', 'aap', 'aapp', 'app', 'zar', 'zaru', 'zarur', 'aru', 'arur', 'rur', 'ban', 'bane', 'baneg', 'banege', 'ane', 'aneg', 'anege', 'neg', 'nege', 'ege', 'mod', 'modi', 'modij', 'modiji', 'odi', 'odij', 'odiji', 'dij', 'diji', 'iji', 'din', 'ani', 'din', 'kha', 'khai', 'hai', 'pop', 'popu', 'popul', 'popula', 'opu', 'opul', 'opula', 'opulat', 'pul', 'pula', 'pulat', 'pulati', 'ula', 'ulat', 'ulati', 'ulatio', 'lat', 'lati', 'latio', 'lation', 'ati', 'atio', 'ation', 'tio', 'tion', 'ion', 'kol', 'kolk', 'kolka', 'kolkat', 'olk', 'olka', 'olkat', 'olkata', 'lka', 'lkat', 'lkata', 'kat', 'kata', 'ata', 'ann', 'anna', 'nna', 'erj', 'erju', 'rju', 'mal', 'mall', 'malli', 'all', 'alli', 'lli', 'vel', 'veli', 'velin', 'velina', 'eli', 'elin', 'elina', 'lin', 'lina', 'ina', 'mov', 'movi', 'movie', 'ovi', 'ovie', 'vie', 'enn', 'enno', 'nno', 'sar', 'sari', 'ari', 'chu', 'chud', 'chuda', 'chudat', 'hud', 'huda', 'hudat', 'hudata', 'uda', 'udat', 'udata', 'udatam', 'dat', 'data', 'datam', 'ata', 'atam', 'tam', 'MAR', 'MARC', 'MARCH', 'MARCHI', 'ARC', 'ARCH' ...

# %%
#0.5714285714285714

from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfTransformer

nb = Pipeline([('vect', CountVectorizer()),
#                ('tfidf', TfidfTransformer()),
               ('clf', MultinomialNB()),
              ])
X_train = new_input
y_train = new_label
nb.fit(X_train, y_train)

#testing
from sklearn.metrics import classification_report

y_pred = nb.predict(X_test)

# %%
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.naive_bayes import MultinomialNB
# from sklearn.pipeline import Pipeline
# from sklearn.feature_extraction.text import TfidfTransformer

# nb = Pipeline([('vect', CountVectorizer()),
#                ('tfidf', TfidfTransformer()),
#                ('clf', RandomForestClassifier(n_estimators=1000, random_state=0)),
#               ])
# X_train = new_input
# y_train = new_label
# nb.fit(X_train, y_train)

# #testing
# from sklearn.metrics import classification_report

# y_pred = nb.predict(X_test)

# %%
# 0.5990062111801242

from sklearn.linear_model import SGDClassifier

sgd = Pipeline([('vect', CountVectorizer()),
#                 ('tfidf', TfidfTransformer()),
                ('clf', SGDClassifier(loss='hinge', penalty='l2',alpha=1e-3, random_state=42, max_iter=5, tol=None)),
               ])
X_train = new_input
y_train = new_label
sgd.fit(X_train, y_train)

# %%time

y_pred = sgd.predict(X_test)

# %%
# #array classifier

# from sklearn.naive_bayes import GaussianNB
# clf = GaussianNB()
# X_train = X_trainActual
# y_train = y_trainActual
# clf.fit(X_train, y_train)

# y_pred=clf.predict(X_test)

# # clf_pf = GaussianNB()
# # clf_pf.partial_fit(X, Y, np.unique(Y))

# # print(clf_pf.predict([[-0.8, -1]]))

# %%
from itertools import islice 
  
y_predActual = []
def convert(lst, var_lst): 
    idx = 0
    for var_len in var_lst: 
        yield np.array(lst[idx : idx + var_len])
        idx += var_len 
var_lst = [len(i) for i in X_testActual]
# print()
y_predActual = list(convert(np.array(y_pred),np.array(var_lst)))
y_predActual
# Out:
# [array(['en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'bn', 'en', 'en', 'en', 'en', 'gu', 'en', 'en', 'te', 'en',
#         'en', 'ml', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en'], dtype='<U2'),
#  array(['te', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en'],
#        dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'te', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['te', 'en', 'en', 'en', 'te', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'te', 'te'], dtype='<U2'),
#  array(['en', 'en', 'hi'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en'],
#        dtype='<U2'),
#  array(['kn', 'kn', 'te'], dtype='<U2'),
#  array(['te', 'te', 'te', 'te', 'te', 'te', 'te', 'te', 'te', 'kn', 'ta',
#         'hi', 'te', 'te', 'hi', 'en', 'te', 'hi', 'en', 'en', 'hi', 'te',
#         'en', 'en', 'te', 'te', 'te', 'te', 'te', 'te', 'te', 'en', 'te',
#         'en', 'te', 'en', 'kn', 'kn'], dtype='<U2'),
#  array(['ta', 'kn', 'kn', 'te', 'kn', 'te'], dtype='<U2'),
#  array(['mr', 'kn', 'en', 'en', 'kn', 'en', 'en', 'en', 'te', 'te', 'en',
#         'te', 'te', 'ta'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'te', 'en', 'en', 'en', 'en', 'en',
#         'en', 'te', 'te', 'en', 'ml', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'te', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en', 'en', 'en', 'en', 'en', 'te', 'en', 'en', 'te',
#         'en', 'en', 'en', 'te', 'te', 'en', 'te', 'en', 'en'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['ta', 'ta', 'en', 'en', 'te', 'te', 'te', 'te', 'te', 'te'],
#        dtype='<U2'),
#  array(['te', 'te', 'te', 'te', 'te', 'en'], dtype='<U2'),
#  array(['te', 'te', 'te'], dtype='<U2'),
#  array(['ml', 'ta', 'kn', 'ta', 'te', 'te'], dtype='<U2'),
#  array(['mr', 'te', 'te', 'en', 'en', 'kn', 'te', 'en', 'kn', 'te', 'en',
#         'en', 'en', 'en', 'en', 'en', 'kn', 'en', 'en', 'te', 'te', 'te'],
#        dtype='<U2'),
#  array(['en', 'bn', 'te'], dtype='<U2'),
#  array(['te', 'bn', 'bn'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'bn', 'en', 'en', 'bn', 'bn', 'en', 'en', 'gu', 'gu', 'bn',
#         'en', 'gu', 'bn', 'en', 'en', 'bn', 'ta'], dtype='<U2'),
#  array(['en', 'bn', 'bn'], dtype='<U2'),
#  array(['hi', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'hi', 'te', 'bn', 'te', 'gu', 'te'],
#        dtype='<U2'),
#  array(['hi', 'hi', 'en', 'te', 'ta', 'ta'], dtype='<U2'),
#  array(['hi', 'en', 'te'], dtype='<U2'),
#  array(['hi', 'en', 'en', 'te', 'en', 'gu'], dtype='<U2'),
#  array(['hi', 'bn', 'en', 'en', 'ml', 'kn', 'en', 'kn', 'en', 'en'],
#        dtype='<U2'),
#  array(['te', 'te', 'en', 'en', 'bn', 'en', 'en', 'en', 'en', 'hi'],
#        dtype='<U2'),
#  array(['ml'], dtype='<U2'),
#  array(['te'], dtype='<U2'),
#  array(['ml'], dtype='<U2'),
#  array(['gu', 'bn', 'hi'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'te', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['kn', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'bn', 'en', 'en',
#         'te', 'te', 'te'], dtype='<U2'),
#  array(['ml', 'kn', 'te'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['mr', 'te', 'te', 'en', 'kn', 'kn'], dtype='<U2'),
#  array(['te', 'te', 'en', 'en', 'en', 'en', 'en', 'en', 'te', 'te'],
#        dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['ta', 'te', 'bn'], dtype='<U2'),
#  array(['te', 'kn', 'te'], dtype='<U2'),
#  array(['ta', 'en', 'en', 'en', 'kn', 'hi', 'en', 'en', 'te', 'en', 'en',
#         'en', 'en', 'te', 'te', 'te', 'te', 'te'], dtype='<U2'),
#  array(['te', 'te', 'te', 'te', 'hi', 'te', 'te', 'te', 'bn', 'te', 'te',
#         'te', 'te', 'te', 'te', 'te', 'te', 'te', 'te', 'te', 'te', 'te',
#         'te', 'te', 'te', 'gu'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['te', 'hi', 'te'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['hi', 'hi', 'gu'], dtype='<U2'),
#  array(['hi', 'hi', 'hi'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['ta', 'te', 'en', 'te', 'gu', 'mr'], dtype='<U2'),
#  array(['hi'], dtype='<U2'),
#  array(['en', 'mr', 'en', 'en', 'mr', 'te', 'te', 'en', 'te', 'te', 'en',
#         'en', 'kn', 'kn'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['hi', 'hi', 'en', 'hi', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'te', 'en', 'kn'], dtype='<U2'),
#  array(['ta', 'hi', 'en', 'en', 'ta', 'en', 'en', 'bn', 'en', 'en'],
#        dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['gu', 'gu', 'gu', 'gu', 'bn', 'gu', 'gu', 'gu', 'te', 'te', 'gu',
#         'gu', 'te', 'gu', 'gu', 'gu', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['kn', 'en', 'en'], dtype='<U2'),
#  array(['bn', 'en', 'te'], dtype='<U2'),
#  array(['bn'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'te', 'en', 'en', 'en', 'te', 'en', 'en',
#         'en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['mr', 'en', 'en'], dtype='<U2'),
#  array(['te', 'te', 'en', 'en', 'te', 'en', 'en', 'ml', 'en', 'en'],
#        dtype='<U2'),
#  array(['ta', 'en', 'en', 'en', 'hi', 'en', 'en', 'en', 'en', 'en'],
#        dtype='<U2'),
#  array(['ta', 'hi', 'hi', 'kn', 'te', 'te'], dtype='<U2'),
#  array(['bn', 'te', 'kn', 'kn', 'en', 'en', 'kn', 'en', 'en', 'kn', 'en',
#         'en', 'kn', 'en', 'en', 'en', 'kn', 'te', 'en', 'en', 'te', 'en',
#         'en', 'en', 'te', 'kn', 'kn', 'te', 'te', 'te'], dtype='<U2'),
#  array(['ta'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'kn'], dtype='<U2'),
#  array(['te', 'en', 'te'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'hi', 'en', 'en', 'en', 'te', 'te', 'en',
#         'en', 'te', 'en', 'en', 'ta', 'en', 'en'], dtype='<U2'),
#  array(['kn', 'en', 'en', 'en', 'bn', 'kn', 'kn', 'kn', 'kn', 'kn'],
#        dtype='<U2'),
#  array(['en', 'te', 'en', 'kn', 'te', 'kn', 'kn', 'en', 'en', 'kn', 'kn',
#         'en', 'kn', 'te', 'en', 'te', 'en', 'te'], dtype='<U2'),
#  array(['kn', 'en', 'en', 'en', 'te', 'te'], dtype='<U2'),
#  array(['ta', 'ta', 'en', 'en', 'en', 'te'], dtype='<U2'),
#  array(['te', 'te', 'en', 'te', 'en', 'kn'], dtype='<U2'),
#  array(['mr', 'kn', 'en', 'en', 'kn', 'en', 'en', 'en', 'te', 'te', 'en',
#         'te', 'te', 'ta'], dtype='<U2'),
#  array(['te', 'te', 'kn', 'kn', 'en', 'gu', 'kn', 'en', 'ta', 'ta', 'en',
#         'en', 'te', 'ta', 'en', 'en', 'ta', 'te', 'en', 'te', 'kn', 'kn'],
#        dtype='<U2'),
#  array(['ta', 'kn', 'en', 'en', 'kn', 'en', 'en', 'en', 'kn', 'mr', 'en',
#         'en', 'mr', 'en', 'en', 'en', 'te', 'te', 'te', 'te', 'te', 'te'],
#        dtype='<U2'),
#  array(['kn', 'te', 'ml'], dtype='<U2'),
#  array(['bn', 'mr', 'gu'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['hi', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'hi', 'en'], dtype='<U2'),
#  array(['te', 'hi', 'hi', 'hi', 'hi', 'hi', 'hi', 'hi', 'hi', 'hi'],
#        dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'ta', 'ta', 'en', 'en', 'te', 'en', 'en',
#         'ml', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en'],
#        dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'te', 'en', 'en', 'te', 'kn', 'en',
#         'en', 'en', 'kn', 'en', 'en', 'te', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'hi', 'en'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['hi'], dtype='<U2'),
#  array(['bn'], dtype='<U2'),
#  array(['te', 'mr', 'mr', 'en', 'en', 'te', 'te', 'te', 'te', 'te'],
#        dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['te', 'te', 'te'], dtype='<U2'),
#  array(['te', 'mr', 'mr', 'en', 'hi', 'te', 'en', 'en', 'te', 'en', 'en',
#         'en', 'en', 'mr'], dtype='<U2'),
#  array(['mr', 'mr', 'gu', 'mr', 'te', 'te', 'mr', 'te', 'te', 'te'],
#        dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'kn', 'en', 'en', 'en', 'en', 'bn', 'en', 'en', 'te', 'te'],
#        dtype='<U2'),
#  array(['hi', 'en', 'en', 'en', 'te', 'te', 'en', 'en', 'te', 'mr', 'mr',
#         'mr', 'te', 'te', 'mr', 'te', 'te', 'te'], dtype='<U2'),
#  array(['te', 'en', 'en', 'bn', 'en', 'bn'], dtype='<U2'),
#  array(['te', 'te', 'en', 'en', 'mr', 'mr', 'en', 'te', 'te', 'te'],
#        dtype='<U2'),
#  array(['bn'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'te', 'en', 'en', 'en', 'en', 'en'],
#        dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'ta', 'en', 'en',
#         'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'te', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'te', 'en', 'en'], dtype='<U2'),
#  array(['te'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'te', 'te', 'en', 'en', 'te', 'en', 'en',
#         'en', 'ta', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'ta', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en'],
#        dtype='<U2'),
#  array(['ta', 'en', 'en'], dtype='<U2'),
#  array(['mr', 'ta', 'te'], dtype='<U2'),
#  array(['bn', 'bn', 'bn', 'bn', 'bn', 'bn', 'bn', 'en', 'en', 'bn', 'en',
#         'en', 'bn', 'bn', 'bn', 'en', 'te', 'bn', 'bn', 'bn', 'bn', 'en',
#         'bn', 'en', 'en', 'en'], dtype='<U2'),
#  array(['te', 'te', 'kn', 'kn', 'en', 'kn', 'kn', 'kn', 'kn', 'kn', 'kn',
#         'kn', 'te', 'kn', 'kn', 'en', 'te', 'te', 'en', 'te', 'te', 'en'],
#        dtype='<U2'),
#  array(['gu', 'en', 'en', 'en', 'bn', 'bn', 'bn', 'bn', 'bn', 'bn'],
#        dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en', 'ml', 'gu', 'bn', 'ta'], dtype='<U2'),
#  array(['en', 'bn', 'en'], dtype='<U2'),
#  array(['ta', 'kn', 'ml', 'ta', 'ta', 'te'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'hi', 'te', 'bn', 'en', 'te', 'gu', 'te',
#         'mr', 'te', 'en', 'mr', 'en', 'mr', 'mr', 'en', 'te', 'en', 'te'],
#        dtype='<U2'),
#  array(['te', 'bn', 'bn', 'en', 'bn', 'en', 'en', 'en', 'en', 'en'],
#        dtype='<U2'),
#  array(['kn'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en'], dtype='<U2'),
#  array(['te', 'bn', 'bn', 'ml', 'te', 'te'], dtype='<U2'),
#  array(['te', 'bn', 'te', 'ml', 'te', 'te'], dtype='<U2'),
#  array(['te', 'te', 'te', 'te', 'te', 'te', 'te', 'te', 'te', 'te'],
#        dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'te', 'en', 'en'],
#        dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['te', 'te', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'ta'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en'],
#        dtype='<U2'),
#  array(['hi', 'hi', 'en', 'hi', 'en', 'en'], dtype='<U2'),
#  array(['hi', 'hi', 'en', 'hi', 'en', 'en'], dtype='<U2'),
#  array(['hi', 'bn', 'te'], dtype='<U2'),
#  array(['en', 'mr', 'en', 'en', 'ml', 'ta', 'en', 'en', 'ta', 'en', 'en',
#         'kn', 'te', 'te'], dtype='<U2'),
#  array(['hi'], dtype='<U2'),
#  array(['hi', 'en', 'en'], dtype='<U2'),
#  array(['te', 'te', 'te'], dtype='<U2'),
#  array(['te', 'te', 'te'], dtype='<U2'),
#  array(['kn'], dtype='<U2'),
#  array(['en', 'gu', 'en', 'en', 'gu', 'ta', 'en', 'en', 'bn', 'hi', 'en',
#         'kn', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en'],
#        dtype='<U2'),
#  array(['kn', 'te', 'en', 'en', 'mr', 'te', 'te', 'te', 'te', 'te'],
#        dtype='<U2'),
#  array(['bn'], dtype='<U2'),
#  array(['bn', 'bn', 'bn', 'bn', 'bn', 'bn', 'bn', 'bn', 'bn', 'bn', 'bn',
#         'te', 'en', 'en'], dtype='<U2'),
#  array(['bn', 'bn', 'bn', 'bn', 'bn', 'bn'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'mr', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['te'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['bn', 'bn', 'bn'], dtype='<U2'),
#  array(['te', 'te', 'te', 'te', 'te', 'te'], dtype='<U2'),
#  array(['ta', 'te', 'kn', 'kn', 'ta', 'ta'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'bn', 'en', 'bn', 'bn', 'te'],
#        dtype='<U2'),
#  array(['te', 'te', 'en', 'en', 'kn', 'en', 'en', 'en', 'te', 'en', 'en',
#         'en', 'hi', 'te', 'en', 'en', 'te', 'te', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['bn', 'bn', 'en'], dtype='<U2'),
#  array(['bn', 'bn', 'bn', 'bn', 'bn', 'bn', 'bn', 'bn', 'bn', 'bn', 'bn',
#         'bn', 'mr', 'te', 'bn', 'en', 'bn', 'bn', 'bn', 'gu', 'bn', 'bn'],
#        dtype='<U2'),
#  array(['en', 'bn', 'bn', 'en', 'bn', 'te'], dtype='<U2'),
#  array(['te', 'en', 'en', 'en', 'bn', 'en', 'en', 'bn', 'bn', 'en'],
#        dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'mr', 'te', 'te',
#         'en', 'te', 'te', 'en', 'te', 'en', 'en'], dtype='<U2'),
#  array(['bn', 'bn', 'en', 'en', 'te', 'en', 'en', 'en', 'en', 'te', 'en',
#         'en', 'mr', 'bn', 'bn', 'gu', 'gu', 'gu'], dtype='<U2'),
#  array(['te', 'gu', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en', 'en', 'en', 'te', 'en', 'en', 'hi', 'bn', 'te'],
#        dtype='<U2'),
#  array(['te', 'kn', 'bn', 'bn', 'te', 'te', 'bn', 'te', 'bn', 'bn'],
#        dtype='<U2'),
#  array(['en', 'ml', 'te', 'bn', 'te', 'te'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'ta', 'en', 'en'],
#        dtype='<U2'),
#  array(['en', 'bn', 'en'], dtype='<U2'),
#  array(['te', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'bn', 'en', 'en',
#         'en', 'gu', 'en', 'en', 'te', 'hi', 'en'], dtype='<U2'),
#  array(['bn', 'bn', 'bn', 'bn', 'bn', 'bn'], dtype='<U2'),
#  array(['te', 'te', 'en', 'en', 'te', 'hi', 'en', 'hi', 'en', 'en'],
#        dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['gu', 'te', 'en', 'en', 'ta', 'te', 'te', 'te', 'te', 'te'],
#        dtype='<U2'),
#  array(['bn', 'bn', 'bn'], dtype='<U2'),
#  array(['bn', 'bn', 'bn', 'en', 'mr', 'bn', 'en', 'en', 'gu', 'bn', 'bn',
#         'bn', 'bn', 'bn', 'bn', 'bn', 'bn', 'bn'], dtype='<U2'),
#  array(['te'], dtype='<U2'),
#  array(['bn', 'bn', 'bn', 'bn', 'bn', 'bn'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['bn', 'en', 'en', 'bn', 'bn', 'te'], dtype='<U2'),
#  array(['te', 'te', 'en', 'te', 'kn', 'bn'], dtype='<U2'),
#  array(['gu', 'bn', 'bn', 'bn', 'bn', 'hi'], dtype='<U2'),
#  array(['ml', 'kn', 'te'], dtype='<U2'),
#  array(['hi', 'te', 'ml'], dtype='<U2'),
#  array(['te', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['te', 'en', 'en', 'te', 'en', 'en'], dtype='<U2'),
#  array(['te', 'te', 'te', 'te', 'te', 'te', 'te', 'te', 'ta', 'te', 'te',
#         'en', 'te', 'te'], dtype='<U2'),
#  array(['te', 'te', 'te', 'te', 'en', 'te', 'te', 'en', 'te', 'te', 'en',
#         'en', 'ta', 'te', 'te', 'te', 'te', 'te'], dtype='<U2'),
#  array(['ta', 'en', 'en', 'en', 'en', 'te'], dtype='<U2'),
#  array(['en', 'en', 'te'], dtype='<U2'),
#  array(['te', 'en', 'en', 'te', 'en', 'en'], dtype='<U2'),
#  array(['te', 'te', 'te', 'te', 'te', 'te', 'te', 'en', 'en', 'te', 'te',
#         'en', 'te', 'te', 'te', 'en', 'en', 'en', 'hi', 'te', 'gu', 'ml'],
#        dtype='<U2'),
#  array(['en', 'te', 'en', 'te', 'te', 'te'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'bn', 'en', 'en'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['mr', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['ta', 'kn', 'kn', 'kn', 'kn', 'kn', 'kn', 'en', 'te', 'kn', 'en',
#         'en', 'en', 'kn', 'en', 'te', 'ta', 'ta'], dtype='<U2'),
#  array(['en', 'en', 'en', 'mr', 'gu', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'te'], dtype='<U2'),
#  array(['ml', 'en', 'en', 'kn', 'te', 'te'], dtype='<U2'),
#  array(['hi', 'hi', 'hi'], dtype='<U2'),
#  array(['en', 'en', 'ta'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'te'], dtype='<U2'),
#  array(['hi'], dtype='<U2'),
#  array(['hi'], dtype='<U2'),
#  array(['hi', 'hi', 'hi'], dtype='<U2'),
#  array(['hi', 'hi', 'hi'], dtype='<U2'),
#  array(['hi', 'hi', 'bn'], dtype='<U2'),
#  array(['te', 'te', 'en', 'en', 'te', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'te', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['te', 'te', 'te', 'te', 'te', 'te', 'te', 'te', 'te', 'te'],
#        dtype='<U2'),
#  array(['ml'], dtype='<U2'),
#  array(['te', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'te', 'te'],
#        dtype='<U2'),
#  array(['te', 'en', 'en', 'en', 'hi', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'te'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['te'], dtype='<U2'),
#  array(['te', 'hi', 'mr', 'en', 'te', 'gu'], dtype='<U2'),
#  array(['hi', 'mr', 'mr'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['ml', 'ml', 'kn'], dtype='<U2'),
#  array(['ta', 'ta', 'kn'], dtype='<U2'),
#  array(['te', 'ta', 'ta', 'te', 'kn', 'ml'], dtype='<U2'),
#  array(['te', 'en', 'en', 'en', 'en', 'te', 'te', 'en', 'te', 'en'],
#        dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ml', 'mr', 'te'],
#        dtype='<U2'),
#  array(['ta', 'ta', 'en', 'en', 'bn', 'kn', 'en', 'en', 'te', 'te', 'ta',
#         'en', 'ta', 'ta', 'ta', 'ta', 'gu', 'ta', 'ta', 'ml', 'ta', 'ta'],
#        dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['ml', 'ta', 'ta', 'ta', 'te', 'te', 'te', 'te', 'te', 'kn', 'te',
#         'ta', 'te', 'te', 'ta', 'ta', 'te', 'ta', 'ta', 'ta', 'bn', 'bn'],
#        dtype='<U2'),
#  array(['te', 'te', 'ml', 'te', 'ta', 'ta'], dtype='<U2'),
#  array(['ta', 'ta', 'ta', 'ta', 'gu', 'ta', 'ta', 'ta', 'ta', 'ta'],
#        dtype='<U2'),
#  array(['ta', 'ta', 'ta', 'te', 'te', 'te'], dtype='<U2'),
#  array(['ta', 'ta', 'gu'], dtype='<U2'),
#  array(['ta', 'ta', 'en', 'en', 'mr', 'ta', 'en', 'en', 'te', 'te', 'te',
#         'en', 'te', 'en', 'en', 'en', 'en', 'te', 'en', 'en', 'kn', 'ta',
#         'en', 'te', 'ta', 'hi'], dtype='<U2'),
#  array(['te'], dtype='<U2'),
#  array(['te', 'ta', 'ta', 'ml', 'ml', 'kn'], dtype='<U2'),
#  array(['ta', 'ta', 'ta', 'en', 'gu', 'ta', 'en', 'en', 'ta', 'en', 'en',
#         'en', 'en', 'en'], dtype='<U2'),
#  array(['ta', 'ta', 'ta', 'ta', 'mr', 'ta', 'ta', 'kn', 'ta', 'ta'],
#        dtype='<U2'),
#  array(['ta', 'te', 'ta', 'ta', 'te', 'ta', 'ta', 'ta', 'kn', 'en'],
#        dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta'],
#        dtype='<U2'),
#  array(['ta', 'ta', 'ta', 'ta', 'mr', 'ta', 'ta', 'kn', 'ta', 'ta'],
#        dtype='<U2'),
#  array(['ml', 'ta', 'ta', 'ta', 'kn', 'kn', 'ta', 'ta', 'ta', 'ta', 'ta',
#         'ta', 'te', 'te', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta',
#         'ta', 'ta', 'ta', 'te'], dtype='<U2'),
#  array(['en', 'te', 'te', 'en', 'te', 'te'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['ta'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en'], dtype='<U2'),
#  array(['te', 'te', 'en', 'te', 'te', 'te'], dtype='<U2'),
#  array(['en', 'ta', 'ta', 'ta', 'ta', 'gu'], dtype='<U2'),
#  array(['ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'en', 'ta', 'ta',
#         'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta',
#         'ta', 'ta', 'ta', 'ta'], dtype='<U2'),
#  array(['en', 'en', 'ta'], dtype='<U2'),
#  array(['ml', 'ta', 'ta', 'ta', 'en', 'ta', 'ta', 'ta', 'ta', 'gu', 'ta',
#         'ta', 'te', 'te', 'ta', 'ta', 'te', 'te', 'ta', 'ta', 'te', 'ta',
#         'ta', 'ta', 'ta', 'ta'], dtype='<U2'),
#  array(['te', 'te', 'te', 'te', 'te', 'te', 'te', 'te', 'te', 'kn', 'ta',
#         'te', 'te', 'te', 'te', 'te', 'te', 'te'], dtype='<U2'),
#  array(['en', 'en', 'ta', 'en', 'en', 'ta', 'te', 'ta', 'ta', 'en', 'ta',
#         'ta', 'en', 'ta', 'ta', 'en', 'ta', 'ta', 'en', 'en', 'ta', 'en',
#         'en', 'en', 'kn', 'kn', 'en', 'en', 'te', 'ta', 'ta', 'ta', 'ta',
#         'ta', 'ta', 'ml', 'ta', 'ta'], dtype='<U2'),
#  array(['ta', 'te', 'ta', 'ta', 'te', 'ta', 'ta', 'ta', 'kn', 'en'],
#        dtype='<U2'),
#  array(['ta'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'bn', 'en', 'en'], dtype='<U2'),
#  array(['ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta',
#         'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en'],
#        dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en', 'en', 'bn', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en'],
#        dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en'],
#        dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en'], dtype='<U2'),
#  array(['ml', 'kn', 'te'], dtype='<U2'),
#  array(['en', 'te', 'en', 'te', 'kn', 'ml'], dtype='<U2'),
#  array(['ta', 'en', 'te'], dtype='<U2'),
#  array(['en', 'te', 'te', 'en', 'en', 'ta', 'en', 'en', 'te', 'en', 'en',
#         'en', 'en', 'en'], dtype='<U2'),
#  array(['kn', 'kn', 'kn', 'en', 'kn', 'kn', 'en', 'en', 'kn', 'en', 'en',
#         'en', 'te', 'kn', 'kn', 'ml', 'kn', 'te'], dtype='<U2'),
#  array(['kn', 'kn', 'en', 'en', 'kn', 'en', 'en', 'kn', 'kn', 'en'],
#        dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en'],
#        dtype='<U2'),
#  array(['hi', 'te', 'te', 'kn', 'en', 'te', 'en', 'kn', 'te', 'kn', 'kn',
#         'en', 'en', 'kn', 'kn', 'en', 'kn', 'te', 'en', 'en', 'te', 'en',
#         'en', 'en', 'te', 'te', 'kn', 'te', 'kn', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['te', 'gu', 'te', 'en', 'te', 'te', 'te', 'en', 'te', 'te', 'en',
#         'en', 'te', 'te'], dtype='<U2'),
#  array(['kn', 'en', 'en', 'ta', 'en', 'en'], dtype='<U2'),
#  array(['hi'], dtype='<U2'),
#  array(['kn', 'hi', 'en', 'ta', 'te', 'gu'], dtype='<U2'),
#  array(['hi', 'en', 'en'], dtype='<U2'),
#  array(['ta', 'gu', 'te'], dtype='<U2'),
#  array(['hi', 'hi', 'ta'], dtype='<U2'),
#  array(['en', 'hi', 'hi', 'hi', 'te', 'te', 'hi', 'hi', 'te', 'hi', 'hi',
#         'te', 'hi', 'kn'], dtype='<U2'),
#  array(['te', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'te', 'te', 'te', 'te', 'te', 'te', 'te', 'te', 'te'],
#        dtype='<U2'),
#  array(['te', 'mr', 'en', 'en', 'kn', 'en', 'en', 'en', 'te', 'en', 'en',
#         'en', 'te', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'te',
#         'en', 'en', 'te', 'te', 'te', 'te', 'te', 'te', 'te', 'te', 'te',
#         'te', 'te', 'te', 'te', 'te'], dtype='<U2'),
#  array(['te', 'te', 'te', 'te', 'te', 'te', 'te', 'te', 'te', 'te', 'te',
#         'te', 'te', 'te', 'te', 'te', 'en', 'te', 'te', 'te', 'te', 'te',
#         'te', 'te', 'te', 'te', 'te', 'te', 'te', 'te'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en'],
#        dtype='<U2'),
#  array(['en', 'en', 'hi'], dtype='<U2'),
#  array(['te'], dtype='<U2'),
#  array(['en', 'te', 'te', 'en', 'en', 'ta', 'en', 'en', 'te', 'en', 'en',
#         'en', 'en', 'en'], dtype='<U2'),
#  array(['ta', 'ta', 'kn', 'gu', 'ml', 'te'], dtype='<U2'),
#  array(['kn', 'kn', 'en', 'en', 'en', 'kn', 'en', 'en', 'kn', 'en', 'en',
#         'kn', 'kn', 'kn'], dtype='<U2'),
#  array(['ta', 'en', 'en', 'en', 'kn', 'en', 'en', 'kn', 'en', 'en'],
#        dtype='<U2'),
#  array(['en', 'ml', 'kn'], dtype='<U2'),
#  array(['kn', 'en', 'en', 'en', 'ta', 'ta', 'en', 'ta', 'en', 'en'],
#        dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['ml', 'te', 'te'], dtype='<U2'),
#  array(['kn', 'en', 'en', 'en', 'en', 'te', 'en', 'en', 'te', 'te', 'en',
#         'te', 'en', 'gu'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['en', 'ta', 'ta'], dtype='<U2'),
#  array(['te', 'te', 'te'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['ta', 'en', 'ta'], dtype='<U2'),
#  array(['te', 'te', 'en', 'en', 'te', 'te'], dtype='<U2'),
#  array(['en', 'te', 'ml', 'te', 'te', 'te', 'en', 'te', 'te', 'te', 'te',
#         'en', 'te', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta',
#         'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta'], dtype='<U2'),
#  array(['ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'en', 'ta', 'ta',
#         'ta', 'ta', 'kn', 'ta', 'en', 'en', 'ta', 'ta', 'ta', 'te', 'te'],
#        dtype='<U2'),
#  array(['ta', 'ta', 'en'], dtype='<U2'),
#  array(['en', 'ta', 'ta', 'kn', 'ta', 'te'], dtype='<U2'),
#  array(['te', 'ml', 'ml', 'ml', 'mr', 'te', 'ml', 'ml', 'te', 'en', 'ml',
#         'en', 'kn', 'ml', 'en', 'en', 'te', 'te', 'gu', 'en', 'en', 'te',
#         'en', 'en', 'ta', 'en', 'en', 'en', 'ta', 'ta', 'ta', 'ta', 'en',
#         'te', 'ta', 'ta', 'kn', 'ta', 'ta', 'en', 'en', 'ta', 'en', 'hi',
#         'te', 'te'], dtype='<U2'),
#  array(['ta', 'ta', 'ta', 'ta', 'en', 'ta', 'ta', 'en', 'ta', 'ta'],
#        dtype='<U2'),
#  array(['en', 'ta', 'ta', 'ta', 'ta', 'gu'], dtype='<U2'),
#  array(['ta'], dtype='<U2'),
#  array(['ta', 'ta', 'ta', 'ta', 'ml', 'ml'], dtype='<U2'),
#  array(['te', 'ta', 'en', 'en', 'kn', 'te', 'ta', 'en', 'te', 'te', 'te',
#         'en', 'te', 'te', 'en', 'te', 'ta', 'ta'], dtype='<U2'),
#  array(['en', 'ml', 'kn'], dtype='<U2'),
#  array(['te', 'te', 'te', 'te', 'en', 'te', 'te', 'te', 'te', 'ta'],
#        dtype='<U2'),
#  array(['te', 'te', 'te', 'en', 'te', 'te', 'en', 'te', 'en', 'te'],
#        dtype='<U2'),
#  array(['te', 'te', 'te', 'te', 'te', 'te'], dtype='<U2'),
#  array(['te', 'en', 'en', 'en', 'te', 'te', 'te', 'te', 'ta', 'ta'],
#        dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'te', 'en', 'en'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'hi', 'en', 'te'], dtype='<U2'),
#  array(['te', 'te', 'te', 'en', 'en', 'te', 'en', 'en', 'kn', 'en', 'en',
#         'en', 'en', 'en', 'en', 'bn', 'ta', 'ta'], dtype='<U2'),
#  array(['te', 'te', 'te'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['en', 'en', 'bn'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'bn', 'en', 'bn', 'kn', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['bn', 'bn', 'bn', 'en', 'en', 'bn', 'en', 'en', 'en', 'en'],
#        dtype='<U2'),
#  array(['bn', 'bn', 'bn'], dtype='<U2'),
#  array(['bn', 'en', 'bn'], dtype='<U2'),
#  array(['bn', 'bn', 'bn'], dtype='<U2'),
#  array(['te', 'hi', 'hi'], dtype='<U2'),
#  array(['en', 'bn', 'en', 'bn', 'en', 'en'], dtype='<U2'),
#  array(['te', 'te', 'en', 'te', 'te', 'te'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'te', 'en',
#         'en', 'en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['ml', 'kn', 'te'], dtype='<U2'),
#  array(['te', 'ta', 'en', 'mr', 'mr', 'te'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['te', 'ta', 'en', 'mr', 'mr', 'te'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'ta', 'ta', 'en', 'te', 'ta', 'ta', 'ml', 'mr'],
#        dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'ml', 'kn'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'ml', 'kn'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['ta'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'te', 'en', 'en', 'te', 'ta', 'ta'],
#        dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['ml', 'kn', 'te', 'te', 'te', 'te', 'te', 'te', 'te', 'te', 'te',
#         'te', 'ta', 'ta'], dtype='<U2'),
#  array(['en', 'te', 'en', 'te', 'kn', 'ml'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'te', 'te', 'en',
#         'en', 'en', 'en'], dtype='<U2'),
#  array(['te', 'te', 'te', 'en', 'te', 'te', 'en', 'en', 'te', 'mr', 'en',
#         'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en'],
#        dtype='<U2'),
#  array(['te'], dtype='<U2'),
#  array(['en', 'te', 'en', 'en', 'te', 'kn'], dtype='<U2'),
#  array(['te', 'te', 'en', 'en', 'te', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'te', 'en', 'en', 'te', 'te', 'en'], dtype='<U2'),
#  array(['en', 'mr', 'en', 'en', 'hi', 'en', 'en', 'en', 'en', 'te'],
#        dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'ta', 'en', 'en', 'ta', 'en', 'en', 'kn', 'en', 'en',
#         'en', 'en', 'en', 'en', 'en', 'te', 'en', 'en', 'en', 'te', 'en',
#         'en', 'en', 'ta', 'en', 'en', 'en', 'te', 'kn', 'en', 'en', 'te',
#         'te', 'te', 'en', 'te', 'te', 'ta', 'en', 'te', 'ta', 'te', 'ta',
#         'ta', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en'],
#        dtype='<U2'),
#  array(['en', 'en', 'hi'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en', 'en', 'kn', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['ta', 'en', 'en'], dtype='<U2'),
#  array(['hi', 'te', 'hi', 'hi', 'en', 'hi', 'hi', 'en', 'hi', 'hi', 'en',
#         'en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['hi'], dtype='<U2'),
#  array(['te', 'hi', 'ml', 'en', 'gu', 'gu'], dtype='<U2'),
#  array(['te'], dtype='<U2'),
#  array(['en', 'te', 'te'], dtype='<U2'),
#  array(['hi', 'gu', 'te'], dtype='<U2'),
#  array(['hi'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['hi', 'en', 'en', 'en', 'en', 'bn'], dtype='<U2'),
#  array(['hi', 'en', 'en', 'en', 'en', 'bn'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'mr'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'bn'], dtype='<U2'),
#  array(['bn', 'bn', 'bn'], dtype='<U2'),
#  array(['kn', 'bn', 'en'], dtype='<U2'),
#  array(['hi', 'bn', 'bn', 'bn', 'ml', 'mr', 'te', 'en', 'bn', 'bn'],
#        dtype='<U2'),
#  array(['te', 'kn', 'te', 'kn', 'en', 'kn', 'te', 'en', 'mr', 'te', 'en',
#         'te', 'en', 'te'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'bn', 'en', 'en', 'en', 'bn', 'en', 'en',
#         'en', 'en', 'bn', 'en', 'bn', 'en', 'te'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'mr', 'ta', 'en',
#         'te', 'en', 'en'], dtype='<U2'),
#  array(['te', 'ta', 'ta'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'te', 'kn'], dtype='<U2'),
#  array(['te', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en'],
#        dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en'],
#        dtype='<U2'),
#  array(['kn', 'bn', 'kn'], dtype='<U2'),
#  array(['te', 'te', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'mr', 'mr', 'gu'], dtype='<U2'),
#  array(['kn'], dtype='<U2'),
#  array(['hi', 'en', 'en'], dtype='<U2'),
#  array(['ta', 'te', 'en', 'en', 'gu', 'ta', 'en', 'en', 'te', 'te', 'en',
#         'te', 'te', 'te'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'mr'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en'],
#        dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'kn', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en'],
#        dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'te', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['kn', 'en', 'mr'], dtype='<U2'),
#  array(['te', 'te', 'en', 'en', 'en', 'kn', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'bn', 'en', 'te'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en'],
#        dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['te', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'ta', 'en', 'en'], dtype='<U2'),
#  array(['bn', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['te', 'te', 'en', 'te', 'te', 'ta'], dtype='<U2'),
#  array(['hi', 'bn', 'en'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['bn', 'bn', 'bn', 'bn', 'bn', 'bn', 'bn', 'bn', 'bn', 'bn', 'bn',
#         'en', 'mr', 'te', 'en', 'en', 'bn', 'en', 'en', 'hi', 'en', 'en'],
#        dtype='<U2'),
#  array(['te', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'ta', 'en', 'en'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'bn', 'en',
#         'bn', 'kn', 'en'], dtype='<U2'),
#  array(['te', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en'],
#        dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['hi', 'bn', 'bn', 'en', 'bn', 'bn', 'en', 'en', 'bn', 'en', 'en',
#         'en', 'te', 'bn', 'bn', 'bn', 'bn', 'bn'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'mr', 'en', 'en',
#         'en', 'gu', 'gu', 'gu', 'en', 'bn', 'bn', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'hi', 'en', 'en', 'hi', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['bn', 'bn', 'bn', 'bn', 'kn', 'bn', 'bn', 'te', 'ta', 'ta'],
#        dtype='<U2'),
#  array(['bn', 'bn', 'bn', 'bn', 'bn', 'te'], dtype='<U2'),
#  array(['bn'], dtype='<U2'),
#  array(['bn'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['ta', 'hi', 'gu'], dtype='<U2'),
#  array(['bn', 'en', 'en', 'en', 'bn', 'en', 'en', 'te', 'te', 'kn'],
#        dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en'], dtype='<U2'),
#  array(['ml', 'en', 'en'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en', 'en', 'en', 'te', 'en', 'en', 'en', 'en', 'en'],
#        dtype='<U2'),
#  array(['gu', 'gu', 'gu', 'gu', 'bn', 'gu', 'gu', 'gu', 'te', 'te', 'gu',
#         'gu', 'te', 'gu', 'gu', 'gu', 'en', 'en'], dtype='<U2'),
#  array(['te', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['te', 'te', 'en', 'te', 'en', 'te'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en'],
#        dtype='<U2'),
#  array(['gu', 'gu', 'gu'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'te', 'en', 'en', 'en', 'ta', 'en', 'en', 'te', 'te', 'en',
#         'en', 'te', 'en', 'en', 'en', 'te', 'te', 'ta', 'ta', 'te', 'te',
#         'ta', 'ta', 'te', 'ta', 'ta', 'ta', 'ta', 'ta'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['te', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en'], dtype='<U2'),
#  array(['te'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['ml', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'te', 'en', 'en'],
#        dtype='<U2'),
#  array(['kn'], dtype='<U2'),
#  array(['ml', 'te', 'ta', 'en', 'te', 'ta', 'ta', 'ta', 'te', 'ta', 'ta',
#         'ta', 'ta', 'ta'], dtype='<U2'),
#  array(['te', 'en', 'te', 'ta', 'te', 'te', 'ta', 'ta', 'te', 'te', 'ta',
#         'en', 'te', 'ta', 'ta', 'ta', 'kn', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en'],
#        dtype='<U2'),
#  array(['kn', 'ta', 'te'], dtype='<U2'),
#  array(['te', 'kn', 'ml', 'kn', 'kn', 'te'], dtype='<U2'),
#  array(['te', 'ta', 'ta', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'gu', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta',
#         'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta'], dtype='<U2'),
#  array(['en', 'ta', 'ta', 'ta', 'ta', 'gu'], dtype='<U2'),
#  array(['en', 'ta', 'ta', 'ta', 'kn', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['te'], dtype='<U2'),
#  array(['ta'], dtype='<U2'),
#  array(['te', 'en', 'en', 'en', 'gu', 'en', 'en', 'en', 'en', 'en'],
#        dtype='<U2'),
#  array(['ta', 'ta', 'te'], dtype='<U2'),
#  array(['ta', 'ta', 'en', 'gu', 'gu', 'ml'], dtype='<U2'),
#  array(['te', 'ta', 'te', 'ta', 'en', 'te', 'ta', 'ta', 'te', 'ta', 'ta',
#         'ta', 'bn', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta',
#         'ta', 'ta', 'ta', 'ta', 'ta', 'ml', 'en', 'en'], dtype='<U2'),
#  array(['ta', 'ta', 'ta', 'ta', 'mr', 'ta', 'ta', 'kn', 'ta', 'ta'],
#        dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'mr', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'bn', 'en', 'en', 'en', 'kn', 'bn', 'te', 'te', 'te', 'te'],
#        dtype='<U2'),
#  array(['ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta',
#         'ta', 'ta', 'ta', 'ta', 'ml', 'mr', 'te'], dtype='<U2'),
#  array(['te', 'te', 'ta', 'ta', 'te', 'bn', 'ta', 'ta', 'en', 'ta', 'ta',
#         'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta'],
#        dtype='<U2'),
#  array(['ta', 'gu', 'gu', 'en', 'te', 'kn', 'en', 'en', 'en', 'en', 'kn',
#         'kn', 'en', 'kn', 'kn', 'en', 'en', 'ta', 'ta', 'kn', 'ta', 'te'],
#        dtype='<U2'),
#  array(['ta', 'hi', 'hi', 'en', 'en', 'hi', 'en', 'en', 'en', 'ta', 'ta',
#         'ta', 'kn', 'en', 'ta', 'en', 'en', 'ta', 'ta', 'kn', 'ta', 'te'],
#        dtype='<U2'),
#  array(['ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'kn', 'te', 'ta',
#         'ta', 'te', 'ta', 'ta', 'ta', 'ta', 'ta'], dtype='<U2'),
#  array(['ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'en', 'ta', 'ta',
#         'en', 'ta', 'kn', 'ta', 'en', 'en', 'en', 'en', 'en', 'te', 'en',
#         'mr', 'en', 'ml', 'ta', 'te', 'en', 'ta', 'ml', 'ta', 'kn', 'ta',
#         'te'], dtype='<U2'),
#  array(['te', 'ta', 'te', 'ta', 'en', 'te', 'ta', 'ta', 'te', 'ta', 'ta',
#         'ta', 'bn', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta',
#         'ta', 'ta', 'ta', 'ta', 'ta', 'ml', 'en', 'en'], dtype='<U2'),
#  array(['ta', 'te', 'ta', 'ta', 'en', 'ta', 'ta', 'ta', 'ta', 'gu'],
#        dtype='<U2'),
#  array(['en', 'ta', 'ta'], dtype='<U2'),
#  array(['te', 'ta', 'ta', 'ta', 'ta', 'te'], dtype='<U2'),
#  array(['en', 'en', 'te'], dtype='<U2'),
#  array(['ml', 'kn', 'kn'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'te', 'en', 'en', 'ml', 'mr', 'ta'],
#        dtype='<U2'),
#  array(['ta', 'ta', 'kn', 'gu', 'ml', 'te'], dtype='<U2'),
#  array(['en', 'ta', 'en', 'en', 'kn', 'ml', 'en', 'en', 'ta', 'en', 'en',
#         'te', 'te', 'te'], dtype='<U2'),
#  array(['hi', 'te', 'te', 'kn', 'en', 'te', 'en', 'en', 'te', 'kn', 'en',
#         'en', 'en', 'kn', 'kn', 'en', 'en', 'kn', 'en', 'en', 'te', 'en',
#         'en', 'te', 'te', 'en'], dtype='<U2'),
#  array(['te', 'te', 'te'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['kn', 'en', 'en', 'en', 'ml', 'en', 'en', 'bn', 'te', 'gu'],
#        dtype='<U2'),
#  array(['gu', 'te', 'en', 'en', 'gu', 'te', 'en', 'en', 'en', 'te', 'en',
#         'te', 'en', 'ta'], dtype='<U2'),
#  array(['hi'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'kn', 'en', 'en', 'ta', 'ta', 'gu'], dtype='<U2'),
#  array(['hi', 'hi', 'te'], dtype='<U2'),
#  array(['te', 'mr', 'en', 'te', 'mr', 'en'], dtype='<U2'),
#  array(['hi', 'hi', 'en'], dtype='<U2'),
#  array(['mr', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['mr', 'hi', 'hi', 'kn', 'hi', 'te'], dtype='<U2'),
#  array(['gu', 'gu', 'mr'], dtype='<U2'),
#  array(['hi', 'gu', 'en', 'en', 'te', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'hi', 'en', 'en', 'en', 'hi', 'en', 'en', 'en', 'en', 'te',
#         'ta', 'ta', 'ta', 'gu', 'te', 'gu', 'ta', 'te'], dtype='<U2'),
#  array(['hi'], dtype='<U2'),
#  array(['en', 'hi', 'en', 'en', 'mr', 'en', 'en', 'te', 'en', 'hi'],
#        dtype='<U2'),
#  array(['ml', 'ta', 'hi', 'en', 'gu', 'en'], dtype='<U2'),
#  array(['hi', 'hi', 'mr'], dtype='<U2'),
#  array(['te', 'bn', 'en', 'te', 'te', 'te'], dtype='<U2'),
#  array(['gu', 'gu', 'mr'], dtype='<U2'),
#  array(['hi', 'gu', 'te'], dtype='<U2'),
#  array(['te', 'te', 'te'], dtype='<U2'),
#  array(['gu', 'gu', 'mr'], dtype='<U2'),
#  array(['hi', 'gu', 'te'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en'],
#        dtype='<U2'),
#  array(['mr', 'te', 'en', 'en', 'te', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['bn', 'bn', 'bn', 'bn', 'bn', 'bn'], dtype='<U2'),
#  array(['te', 'en', 'mr'], dtype='<U2'),
#  array(['ta'], dtype='<U2'),
#  array(['bn', 'bn', 'bn'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['ml', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en'],
#        dtype='<U2'),
#  array(['hi', 'en', 'en'], dtype='<U2'),
#  array(['hi', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'ta', 'en', 'en', 'te', 'en', 'te'],
#        dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'bn', 'en', 'en', 'en', 'bn', 'bn', 'bn',
#         'gu', 'en', 'te'], dtype='<U2'),
#  array(['te', 'bn', 'bn', 'te', 'bn', 'te'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'mr', 'te', 'te',
#         'en', 'te', 'te', 'en', 'te', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'te', 'en', 'en'],
#        dtype='<U2'),
#  array(['te'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'te', 'te', 'te', 'te', 'te', 'te'],
#        dtype='<U2'),
#  array(['en', 'bn', 'bn', 'te', 'bn', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['bn', 'bn', 'bn', 'bn', 'bn', 'bn', 'bn', 'bn', 'bn', 'bn'],
#        dtype='<U2'),
#  array(['gu', 'en', 'bn', 'bn', 'te', 'te', 'bn', 'te', 'te', 'te'],
#        dtype='<U2'),
#  array(['bn'], dtype='<U2'),
#  array(['hi', 'hi', 'hi', 'hi', 'hi', 'hi'], dtype='<U2'),
#  array(['gu'], dtype='<U2'),
#  array(['te', 'hi', 'ml'], dtype='<U2'),
#  array(['gu'], dtype='<U2'),
#  array(['mr', 'mr', 'en', 'en', 'hi', 'en', 'en', 'en', 'mr', 'mr', 'en',
#         'en', 'mr', 'mr', 'te', 'en', 'te', 'te', 'en', 'te', 'gu', 'ml'],
#        dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en'],
#        dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en'],
#        dtype='<U2'),
#  array(['kn', 'ml', 'ml', 'en', 'en', 'ta', 'bn', 'kn', 'ta', 'te'],
#        dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'kn', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'te'],
#        dtype='<U2'),
#  array(['en', 'ta', 'kn'], dtype='<U2'),
#  array(['te', 'te', 'te', 'en', 'mr', 'te', 'en', 'en', 'te', 'te', 'en',
# ...
#  array(['en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['hi', 'bn', 'bn'], dtype='<U2'),
#  array(['kn'], dtype='<U2'),
#  array(['hi', 'en', 'en', 'en', 'gu', 'en', 'en', 'te', 'te', 'te'],
#        dtype='<U2'),
#  array(['mr', 'hi', 'en'], dtype='<U2'),
#  array(['hi', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['te', 'mr', 'en', 'hi', 'hi', 'te'], dtype='<U2'),
#  array(['ta', 'en', 'kn'], dtype='<U2'),
#  array(['te', 'te', 'ta'], dtype='<U2'),
#  array(['mr'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['hi', 'hi', 'hi'], dtype='<U2'),
#  array(['mr', 'hi', 'kn'], dtype='<U2'),
#  array(['hi', 'en', 'hi'], dtype='<U2'),
#  array(['te'], dtype='<U2'),
#  array(['hi'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['hi'], dtype='<U2'),
#  array(['ta', 'ta', 'en', 'en', 'bn', 'bn'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['hi'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['te', 'te', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en'],
#        dtype='<U2'),
#  array(['te'], dtype='<U2'),
#  array(['te', 'te', 'gu', 'te', 'gu', 'te'], dtype='<U2'),
#  array(['en', 'hi', 'te', 'en', 'mr', 'te', 'te', 'te', 'te', 'ml'],
#        dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en'],
#        dtype='<U2'),
#  array(['ta', 'en', 'ta'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['te'], dtype='<U2'),
#  array(['en', 'en', 'bn'], dtype='<U2'),
#  array(['te', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'te', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'te', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'te', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'te'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['te', 'mr', 'mr', 'kn', 'hi', 'kn', 'kn', 'mr', 'en', 'mr', 'kn',
#         'en', 'kn', 'mr', 'en', 'en', 'te', 'gu', 'en', 'en', 'te', 'en',
#         'en', 'en', 'te', 'en', 'en', 'en', 'te', 'te', 'en', 'en', 'te',
#         'en', 'en', 'en', 'en', 'te', 'te', 'te', 'te', 'te', 'te', 'te',
#         'te', 'kn', 'te', 'te', 'te', 'te', 'te', 'te', 'te', 'te'],
#        dtype='<U2'),
#  array(['te', 'te', 'te', 'en', 'ta', 'kn', 'en', 'en', 'te', 'en', 'te',
#         'en', 'te', 'te'], dtype='<U2'),
#  array(['te', 'te', 'te'], dtype='<U2'),
#  array(['en', 'te', 'en', 'en', 'te', 'te', 'en', 'en', 'te', 'en', 'en',
#         'en', 'bn', 'te', 'ml', 'en', 'te', 'kn', 'en', 'en', 'kn', 'en',
#         'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'te',
#         'te', 'te', 'te', 'te', 'te'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['kn', 'mr', 'en', 'en', 'te', 'ta', 'en', 'en', 'ta', 'bn', 'en',
#         'en', 'gu', 'ta', 'en', 'en', 'te', 'te', 'en', 'en', 'te', 'en',
#         'en', 'en', 'te', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['te', 'te', 'te'], dtype='<U2'),
#  array(['en', 'en', 'te'], dtype='<U2'),
#  array(['te'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'te', 'te', 'te', 'en', 'te', 'te', 'en',
#         'te', 'te', 'gu'], dtype='<U2'),
#  array(['en', 'bn', 'bn'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en'],
#        dtype='<U2'),
#  array(['ta', 'en', 'en'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['hi'], dtype='<U2'),
#  array(['en', 'bn', 'bn'], dtype='<U2'),
#  array(['hi'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'te', 'en', 'en',
#         'ml', 'en', 'en'], dtype='<U2'),
#  array(['bn', 'bn', 'bn'], dtype='<U2'),
#  array(['te', 'te', 'te', 'en', 'mr', 'te', 'en', 'te', 'en', 'en'],
#        dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'ta', 'en', 'en', 'en', 'te', 'gu', 'ta',
#         'en', 'gu', 'ta', 'en', 'en', 'ta', 'te', 'te', 'gu', 'te', 'te'],
#        dtype='<U2'),
#  array(['te', 'en', 'te', 'en', 'en', 'te', 'en', 'en', 'ml', 'en', 'en',
#         'en', 'en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['hi', 'hi', 'en'], dtype='<U2'),
#  array(['hi', 'hi', 'te'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['bn', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'te'], dtype='<U2'),
#  array(['te', 'bn', 'en', 'en', 'en', 'te'], dtype='<U2'),
#  array(['hi', 'en', 'en', 'ml', 'te', 'ta'], dtype='<U2'),
#  array(['bn', 'hi', 'en', 'en', 'kn', 'te', 'en', 'en', 'bn', 'kn', 'kn',
#         'en', 'kn', 'en'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'te', 'ta', 'ta', 'ta', 'ml', 'gu'],
#        dtype='<U2'),
#  array(['te', 'te', 'te'], dtype='<U2'),
#  array(['en', 'te', 'te'], dtype='<U2'),
#  array(['te', 'en', 'en', 'mr', 'en', 'hi'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en'],
#        dtype='<U2'),
#  array(['ml', 'ta', 'te', 'en', 'ta', 'te', 'en', 'te', 'en', 'kn'],
#        dtype='<U2'),
#  array(['te', 'gu', 'en', 'en', 'hi', 'en', 'en', 'en', 'hi', 'te', 'te',
#         'en', 'ta', 'te', 'en', 'te', 'kn', 'en'], dtype='<U2'),
#  array(['gu', 'te', 'te'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'mr', 'en', 'gu'],
#        dtype='<U2'),
#  array(['ta', 'gu', 'te', 'gu', 'te', 'te'], dtype='<U2'),
#  array(['gu', 'ta', 'te', 'en', 'te', 'te', 'en', 'en', 'kn', 'kn', 'en',
#         'en', 'te', 'bn', 'en', 'te', 'te', 'en'], dtype='<U2'),
#  array(['mr', 'bn', 'en'], dtype='<U2'),
#  array(['gu', 'mr', 'mr', 'en', 'en', 'te'], dtype='<U2'),
#  array(['te', 'te', 'te', 'te', 'en', 'te', 'te', 'en', 'te', 'gu', 'te',
#         'en', 'te', 'ta', 'ta', 'gu', 'ta', 'ml'], dtype='<U2'),
#  array(['te', 'te', 'te', 'en', 'te', 'te', 'en', 'en', 'te', 'en', 'en',
#         'en', 'en', 'hi'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'mr', 'en', 'en', 'en', 'en', 'en', 'en',
#         'te', 'te', 'en'], dtype='<U2'),
#  array(['mr', 'mr', 'mr', 'en', 'mr', 'mr', 'mr', 'mr', 'mr', 'te'],
#        dtype='<U2'),
#  array(['te', 'en', 'mr', 'bn', 'gu', 'mr'], dtype='<U2'),
#  array(['te'], dtype='<U2'),
#  array(['te', 'en', 'mr', 'bn', 'gu', 'mr'], dtype='<U2'),
#  array(['hi', 'en', 'en', 'en', 'te', 'te', 'te', 'en', 'te', 'te', 'en',
#         'en', 'te', 'en', 'en', 'en', 'kn', 'bn', 'en', 'ta', 'te', 'te'],
#        dtype='<U2'),
#  array(['en', 'ml', 'kn'], dtype='<U2'),
#  array(['ml', 'kn', 'en', 'en', 'kn', 'en', 'en', 'en', 'ta', 'en', 'en',
#         'en', 'te', 'en', 'en', 'kn', 'kn', 'kn'], dtype='<U2'),
#  array(['te', 'mr', 'te', 'te', 'te', 'te', 'te', 'en', 'te', 'te', 'te',
#         'te', 'te', 'te', 'te', 'ml', 'kn', 'te'], dtype='<U2'),
#  array(['en', 'kn', 'kn', 'kn', 'en', 'kn', 'kn', 'en', 'gu', 'te', 'en',
#         'en', 'ta', 'en', 'en', 'en', 'en', 'en', 'en', 'ta', 'te', 'en'],
#        dtype='<U2'),
#  array(['kn', 'kn', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en'],
#        dtype='<U2'),
#  array(['ta', 'ta', 'kn', 'gu', 'ml', 'te'], dtype='<U2'),
#  array(['hi', 'en', 'en', 'en', 'te', 'te', 'te', 'en', 'te', 'te', 'en',
#         'en', 'te', 'en', 'en', 'en', 'kn', 'bn', 'en', 'en', 'ta', 'te',
#         'en', 'en', 'te', 'te', 'en', 'en', 'kn', 'ml', 'en', 'en', 'te',
#         'te', 'te', 'en', 'ta', 'te', 'en', 'en', 'te', 'hi', 'en', 'en',
#         'en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en'],
#        dtype='<U2'),
#  array(['ml', 'te', 'mr', 'te', 'te', 'ta'], dtype='<U2'),
#  array(['en', 'mr', 'mr', 'mr', 'mr', 'te'], dtype='<U2'),
#  array(['gu', 'en', 'bn', 'mr', 'te', 'te', 'en', 'mr', 'te', 'mr', 'mr',
#         'en', 'te', 'mr'], dtype='<U2'),
#  array(['te', 'te', 'te'], dtype='<U2'),
#  array(['te', 'te', 'en', 'en', 'te', 'te', 'te', 'en', 'te', 'te', 'en',
#         'en', 'te', 'mr', 'mr', 'mr', 'en', 'mr', 'mr', 'te', 'mr', 'mr'],
#        dtype='<U2'),
#  array(['te', 'mr', 'mr', 'en', 'hi', 'te', 'en', 'en', 'te', 'te', 'en',
#         'en', 'te', 'te', 'en', 'en', 'kn', 'kn', 'en', 'en', 'te', 'en',
#         'en', 'en', 'te', 'en', 'te', 'te', 'te', 'te'], dtype='<U2'),
#  array(['te', 'mr', 'en', 'en', 'te', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en', 'en', 'en', 'en', 'te'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'te', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en', 'en', 'en', 'en', 'bn', 'en', 'en', 'en', 'bn',
#         'bn'], dtype='<U2'),
#  array(['te', 'te', 'te'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'te', 'en', 'en'], dtype='<U2'),
#  array(['ml'], dtype='<U2'),
#  array(['te', 'te', 'te'], dtype='<U2'),
#  array(['bn'], dtype='<U2'),
#  array(['te'], dtype='<U2'),
#  array(['te', 'te', 'te'], dtype='<U2'),
#  array(['ta', 'te', 'kn', 'en', 'kn', 'ta', 'ta', 'ta', 'ta', 'ta'],
#        dtype='<U2'),
#  array(['gu'], dtype='<U2'),
#  array(['hi'], dtype='<U2'),
#  array(['te', 'kn', 'ml'], dtype='<U2'),
#  array(['ml', 'en', 'en', 'gu', 'en', 'en'], dtype='<U2'),
#  array(['gu'], dtype='<U2'),
#  array(['ml'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'te', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en'],
#        dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'mr'],
#        dtype='<U2'),
#  array(['te'], dtype='<U2'),
#  array(['mr', 'mr', 'en', 'en', 'te', 'te'], dtype='<U2'),
#  array(['gu', 'hi', 'mr', 'te', 'te', 'te'], dtype='<U2'),
#  array(['hi', 'hi', 'mr'], dtype='<U2'),
#  array(['hi', 'hi', 'en'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['en', 'hi', 'hi', 'hi', 'te', 'te', 'hi', 'hi', 'te', 'hi', 'hi',
#         'te', 'hi', 'kn'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'mr'], dtype='<U2'),
#  array(['te', 'te', 'en', 'en', 'te', 'te', 'en', 'te', 'ml', 'te'],
#        dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'ta', 'en', 'en', 'te', 'en', 'te'],
#        dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en'], dtype='<U2'),
#  array(['gu', 'en', 'en', 'en', 'en', 'te'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en', 'en', 'en', 'te', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'kn', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'te', 'en', 'en', 'en', 'en', 'te', 'kn',
#         'te', 'te', 'te'], dtype='<U2'),
#  array(['bn', 'bn', 'bn'], dtype='<U2'),
#  array(['gu', 'te', 'en', 'te', 'en', 'en'], dtype='<U2'),
#  array(['hi', 'te', 'kn'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['te', 'en', 'en'], dtype='<U2'),
#  array(['bn', 'bn', 'bn', 'bn', 'bn', 'bn', 'bn', 'en', 'bn', 'bn'],
#        dtype='<U2'),
#  array(['en', 'te', 'en', 'hi', 'te', 'te'], dtype='<U2'),
#  array(['en', 'en', 'ta'], dtype='<U2'),
#  array(['en', 'ml', 'bn', 'te', 'bn', 'en'], dtype='<U2'),
#  array(['en', 'bn', 'ta'], dtype='<U2'),
#  array(['en', 'en', 'ta'], dtype='<U2'),
#  array(['en', 'en', 'ta'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en'],
#        dtype='<U2'),
#  array(['en', 'en', 'ta'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'te', 'en', 'en',
#         'en', 'en', 'en', 'en', 'te', 'en', 'en'], dtype='<U2'),
#  array(['te', 'bn', 'bn'], dtype='<U2'),
#  array(['bn'], dtype='<U2'),
#  array(['kn', 'te', 'te'], dtype='<U2'),
#  array(['bn'], dtype='<U2'),
#  array(['en', 'bn', 'en', 'en', 'bn', 'en', 'en', 'bn', 'bn', 'en'],
#        dtype='<U2'),
#  array(['mr', 'en', 'en', 'hi', 'te', 'te'], dtype='<U2'),
#  array(['te', 'te', 'en', 'en', 'te', 'kn', 'en', 'en', 'te', 'en', 'en',
#         'en', 'en', 'te', 'en', 'en', 'te', 'kn', 'en', 'en', 'kn', 'en',
#         'en', 'en', 'bn', 'te', 'en', 'en', 'gu', 'bn'], dtype='<U2'),
#  array(['en', 'te', 'te'], dtype='<U2'),
#  array(['bn'], dtype='<U2'),
#  array(['bn', 'bn', 'en', 'bn', 'en', 'bn'], dtype='<U2'),
#  array(['bn', 'bn', 'bn', 'en', 'bn', 'en'], dtype='<U2'),
#  array(['ta', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en'],
#        dtype='<U2'),
#  array(['bn', 'bn', 'bn'], dtype='<U2'),
#  array(['bn', 'kn', 'ta'], dtype='<U2'),
#  array(['te', 'en', 'en', 'mr', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'gu', 'en', 'en', 'bn', 'bn', 'bn'],
#        dtype='<U2'),
#  array(['kn', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'mr', 'en', 'en',
#         'en', 'en', 'ta', 'en', 'en', 'kn', 'te', 'en', 'en', 'en', 'en',
#         'en', 'en', 'te', 'en', 'en', 'ta', 'ta', 'kn'], dtype='<U2'),
#  array(['bn'], dtype='<U2'),
#  array(['ml', 'bn', 'bn'], dtype='<U2'),
#  array(['te', 'bn', 'en', 'te', 'en', 'bn'], dtype='<U2'),
#  array(['mr', 'ta', 'te'], dtype='<U2'),
#  array(['hi', 'te', 'kn'], dtype='<U2'),
#  array(['en', 'bn', 'bn', 'bn', 'bn', 'bn'], dtype='<U2'),
#  array(['te'], dtype='<U2'),
#  array(['te', 'gu', 'gu', 'gu', 'te', 'ta', 'gu', 'kn', 'en', 'te'],
#        dtype='<U2'),
#  array(['bn', 'bn', 'en', 'en', 'en', 'bn', 'bn', 'te', 'bn', 'kn'],
#        dtype='<U2'),
#  array(['te', 'en', 'en', 'te', 'en', 'en'], dtype='<U2'),
#  array(['ta', 'ta', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en'],
#        dtype='<U2'),
#  array(['ta', 'ta', 'ta'], dtype='<U2'),
#  array(['te', 'te', 'ta', 'en', 'te', 'te', 'en', 'en', 'te', 'en', 'en',
#         'en', 'ta', 'ta'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'te', 'mr', 'en',
#         'en', 'te', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['en'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'bn', 'en', 'en', 'bn', 'en', 'en', 'en', 'bn', 'en', 'en',
#         'en', 'en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en',
#         'en', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en'], dtype='<U2'),
#  array(['bn', 'ta', 'ta', 'ta', 'te', 'ta', 'ta', 'ta', 'gu', 'ta', 'ta',
#         'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta', 'ta',
#         'ta', 'ta', 'ta', 'ta'], dtype='<U2'),
#  array(['ml', 'ta', 'ta', 'ta', 'te', 'te', 'te', 'te', 'te', 'kn', 'te',
#         'te', 'te', 'te'], dtype='<U2'),
#  array(['en', 'ta', 'ta', 'ta', 'ta', 'gu'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'kn', 'en', 'en', 'en', 'te', 'en', 'en',
#         'ml', 'en', 'en'], dtype='<U2'),
#  array(['en', 'en', 'en', 'en', 'te', 'en', 'en', 'en', 'en', 'en'],
#        dtype='<U2'),
#  array(['en', 'bn', 'en', 'en', 'bn', 'en', 'en', 'en', 'bn', 'en', 'en',
#         'en', 'en', 'en', 'en', 'en', 'en', 'en'], dtype='<U2'),
#  ...]

# %%
len(y_predActual)
print(len(y_testActual))
# Out:
# 8050

# %%
y_predConfined=[]
for wordlist in y_predActual:
  
    countele = np.unique(wordlist, return_counts=True)
    
    index = list(countele[1]).index(max(countele[1]))
#     print("Countele",countele,"index",index)
    y_predConfined.append(countele[0][index])
#     y_predExtract.append(finalele)
    
len(y_predConfined)
# Out:
# 8050

# %%
print('accuracy %s' % accuracy_score(y_predConfined, y_testActual))
# Out:
# accuracy 0.5983850931677018
